# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
path = "../inside_airbnb_listings/summary/"
filename = '02-01-2017.csv'
df = pd.read_csv(path + filename, encoding='ISO-8859-1', low_memory=False)

# %%
path = "../inside_airbnb_listings/detailed/"
filename = 'listings_april_2015.csv'
df2 = pd.read_csv(path + filename, encoding='ISO-8859-1', low_memory=False)

# %%
path = "../tom_slee/results/"
filename = 'all_tom_slee_listings_with_m2.csv'
tslee = pd.read_csv(path + filename, encoding='ISO-8859-1', low_memory=False)

# %%
merged = pd.concat([df, df2])

# %%
tslee.corr(method='pearson',min_periods=5).abs()
# Out:
#                       Unnamed: 0  Unnamed: 0.1  accommodates  bathrooms  \
# Unnamed: 0              1.000000      0.365623      0.053806        NaN
# Unnamed: 0.1            0.365623      1.000000      0.332840        NaN
# accommodates            0.053806      0.332840      1.000000        NaN
# bathrooms                    NaN           NaN           NaN        NaN
# bedrooms                0.027826      0.328442      0.702034        NaN
# borough                      NaN           NaN           NaN        NaN
# country                      NaN           NaN           NaN        NaN
# host_id                 0.260481      0.141189      0.006223        NaN
# latitude                0.004998      0.061226      0.018670        NaN
# longitude               0.002309      0.011069      0.091860        NaN
# minstay                 0.010579      0.024890      0.018955        NaN
# overall_satisfaction    0.196560      0.039627      0.027669        NaN
# ...

# %%
tslee.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'accommodates', 'bathrooms', 'bedrooms',
#        'borough', 'city', 'country', 'host_id', 'last_modified', 'latitude',
#        'location', 'longitude', 'minstay', 'name', 'neighborhood',
#        'overall_satisfaction', 'price', 'reviews', 'room_id', 'room_type',
#        'survey_id', 'm2'],
#       dtype='object')

# %%
price_plot_plot =  sns.jointplot('price','m2',data=tslee, kind='reg', color = 'r')

# %%
 tslee['price'].describe()['mean'] / tslee['m2'].describe()['mean']
# Out:
# 1.5770331692541184

# %%
 tslee['price'].div(tslee['m2']).describe()
# Out:
# count    1726.000000
# mean        2.163541
# std         1.230891
# min         0.641667
# 25%         1.492308
# 50%         1.850806
# 75%         2.437216
# max        12.892857
# dtype: float64

# %%
 tslee['price'].describe()['mean']
# Out:
# 155.83024740225372

# %%
 tslee['m2'].describe()['mean']
# Out:
# 98.812282734646587
